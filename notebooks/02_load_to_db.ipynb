# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.import_db import csv_to_db

# %% [markdown]
# #### Order to insert data:
# 1- Customer Geolocation
# 2- Order Customer
# 3- Orders
# 4- Order Payments
# 5- Order Reviews
# 6- Order Items
# 7- Sellers
# 8- Products
# 9- Product Category Translation

# %%
csv_to_db('../data/olist_geolocation_dataset.csv', 'geolocation')
# Out:
# Tabla geolocation cargada

# %%
csv_to_db('../data/olist_customers_dataset.csv', 'customers')
# Out:
# Tabla customers cargada

# %%
csv_to_db('../data/olist_orders_dataset.csv', 'orders')
# Out:
# Tabla orders cargada

# %%
csv_to_db('../data/olist_order_payments_dataset.csv', 'order_payments')
# Out:
# Tabla order_payments cargada

# %%
csv_to_db('../data/olist_order_reviews_dataset.csv', 'order_reviews')
# Out:
# Tabla order_reviews cargada

# %%
csv_to_db('../data/olist_order_items_dataset.csv', 'order_items')
# Out:
# Tabla order_items cargada

# %%
csv_to_db('../data/olist_sellers_dataset.csv', 'sellers')
# Out:
# Tabla sellers cargada

# %%
csv_to_db('../data/olist_products_dataset.csv', 'products')
# Out:
# Tabla products cargada

# %%
csv_to_db('../data/product_category_name_translation.csv', 'product_category_name_translation')
# Out:
# Tabla product_category_name_translation cargada
