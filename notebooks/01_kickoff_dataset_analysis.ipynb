# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd
from src.load_data import explore_dataset

# %%
orders = pd.read_csv('../data/olist_orders_dataset.csv')
order_customers = pd.read_csv('../data/olist_customers_dataset.csv')
order_payments = pd.read_csv('../data/olist_order_payments_dataset.csv')
order_items = pd.read_csv('../data/olist_order_items_dataset.csv')
order_reviews = pd.read_csv('../data/olist_order_reviews_dataset.csv')
customer_geolocation = pd.read_csv('../data/olist_geolocation_dataset.csv')
item_products = pd.read_csv('../data/olist_products_dataset.csv')
item_sellers = pd.read_csv('../data/olist_sellers_dataset.csv')

# %% [markdown]
# ## Dataset Overview
#
# This section explores:
# - dataset dimensions
# - column types
# - missing values
# - duplicates
# - statistical summary

# %% [markdown]
# #### 1. Explore Orders + Related Tables

# %%
explore_dataset(orders, "Orders")
# Out:
# Dataset: Orders
# --------------------------------------------------
# Shape: (99441, 8)
# --------------------------------------------------
# Columns: Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object
# --------------------------------------------------
# Missing values:
#  order_id                            0
# customer_id                         0
# order_status                        0
# ...

# %% [markdown]
# #### 2. Explore Customers

# %%
explore_dataset(order_customers, "Customers")
# Out:
# Dataset: Customers
# --------------------------------------------------
# Shape: (99441, 5)
# --------------------------------------------------
# Columns: Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object
# --------------------------------------------------
# Missing values:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# --------------------------------------------------
#
# Sample data:
#                          customer_id                customer_unique_id  \
# ...

# %% [markdown]
# #### 3. Explore Payments

# %%
explore_dataset(order_payments, "Payments")
# Out:
# Dataset: Payments
# --------------------------------------------------
# Shape: (103886, 5)
# --------------------------------------------------
# Columns: Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object
# --------------------------------------------------
# Missing values:
#  order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# --------------------------------------------------
#
# Sample data:
#                             order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# ...

# %% [markdown]
# #### 4. Explore Items

# %%
explore_dataset(order_items, "Items")
# Out:
# Dataset: Items
# --------------------------------------------------
# Shape: (112650, 7)
# --------------------------------------------------
# Columns: Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object
# --------------------------------------------------
# Missing values:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# --------------------------------------------------
#
# Sample data:
# ...

# %% [markdown]
# #### 5. Explore Reviews

# %%
explore_dataset(order_reviews, "Reviews")
# Out:
# Dataset: Reviews
# --------------------------------------------------
# Shape: (99224, 7)
# --------------------------------------------------
# Columns: Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object
# --------------------------------------------------
# Missing values:
#  review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# ...

# %% [markdown]
# #### 6. Explore Geolocation

# %%
explore_dataset(customer_geolocation, "Geolocation")
# Out:
# Dataset: Geolocation
# --------------------------------------------------
# Shape: (1000163, 5)
# --------------------------------------------------
# Columns: Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                   str
# geolocation_state                  str
# dtype: object
# --------------------------------------------------
# Missing values:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
# --------------------------------------------------
#
# Sample data:
# ...

# %% [markdown]
# #### 7. Explore Sellers

# %%
explore_dataset(item_sellers, "Sellers")
# Out:
# Dataset: Sellers
# --------------------------------------------------
# Shape: (3095, 4)
# --------------------------------------------------
# Columns: Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='str')
# --------------------------------------------------
# Data types:
#  seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object
# --------------------------------------------------
# Missing values:
#  seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
# --------------------------------------------------
#
# Sample data:
#                            seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# ...

# %% [markdown]
# #### 8. Explore Products

# %%
explore_dataset(item_products, "Products")
# Out:
# Dataset: Products
# --------------------------------------------------
# Shape: (32951, 9)
# --------------------------------------------------
# Columns: Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='str')
# --------------------------------------------------
# Data types:
#  product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
# --------------------------------------------------
# Missing values:
#  product_id                      0
# product_category_name         610
# ...
